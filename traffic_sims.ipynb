# %% [markdown]
# #Traffic Simulations of Driver Behavior on 1km  Roadway

# %% [markdown]
# I analyzed the behavior of drivers on a 1km length of road to determine the optimal speed limit. The number of cars on the roadway is first set to 30 and speed limit recommendations are compared with 1, 9 and 1000 simulations. Speed limit recommendations are then recalculated assuming the number of cars on the roadway varies between 20, 40, and 50. An additional 100 simulations are run with each variation of set number of cars.

# %%
from simulation import Simulation
from car import Car
from simulation import n_simulations
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ##1. Traffic Simulations: 30 cars, 1 simulation

# %%
#Setting car and simulation variables.
num_cars = 30
num_simulations = 1

#Calculating the mean speeds and standard deviation.
one_simulation = n_simulations(num_simulations, num_cars)
speed_of_one = [one_simulation[i][1][61:] for i in range(len(one_simulation))]
mean_speed_one = [np.mean(speed_of_one[i]) for i in range(len(speed_of_one))]
stdev_of_one = [np.std(speed_of_one[i]) for i in range(len(speed_of_one))]
print("{} cars, {} simulation:".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speed_one))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_of_one))))
print("  Recommended speed limit is {} m/s"\
      .format(round(np.mean(mean_speed_one) + (round(np.mean(stdev_of_one))))))

##Scatter plot using plt.scatter
x = one_simulation[0][0]
y = [[i]*num_cars for i in range(121)]
plt.subplots_adjust(left=18, right=20, top=20, bottom=18)
plt.scatter(x, y, marker="|", c=['g', 'r', 'y', 'b'])
plt.xlabel("Length of Road (meters)", fontsize=18)
plt.ylabel("Time (seconds)", fontsize=18)
plt.title("Traffic Simulation: {} cars, {} simulation".format(num_cars, num_simulations), fontsize=15)
plt.hlines(60, 0, 1000, color='r')
plt.text(-175, 75, "Mean = {}".format(round(np.mean(mean_speed_one))), color='r', fontsize=14)
plt.text(-175, 70, "StDev = {}".format(round(np.mean(stdev_of_one))), color='r', fontsize=14)
plt.text(-175, 60, "Data Point", color='r', fontsize=14)
# Out:
# 30 cars, 1 simulation:
#   Mean speed: 15.0 m/s
#   Standard Deviation: 12.0
#   Recommended speed limit is 27.0 m/s

# %% [markdown]
# The redline indiactes the 60 second mark. The mean speed and standard deviation was calculated from 60s to 120s. The backup of cars begins around 500 meters.

# %% [markdown]
# ##2. Traffic Simulation: 30 cars, 9 simulations

# %% [markdown]
# The results show 30 cars moving through a 1km of road in a 120 second interval nine times.

# %%
#Setting car and simulation variables.
num_cars = 30
num_simulations = 9

#Calculating the mean speeds and standard deviation.
nine_simulations = n_simulations(num_simulations, num_cars)
speeds_of_nine = [nine_simulations[i][1][61:] for i in range(len(nine_simulations))]
mean_speeds_of_nine = [np.mean(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
stdev_of_nine = [np.std(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
print("{} cars, {} simulations:".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speeds_of_nine))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_of_nine))))
print("  Recommended speed limit is {} m/s".format(round(np.mean(mean_speeds_of_nine) +np.mean(stdev_of_nine))))

#Nine scatter plots using plt.sublplots
f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex='col', sharey='row')
plt.subplots_adjust(left=18, right=20, top=20, bottom=18)
y = [[i]*30 for i in range(121)]
x = [nine_simulations[i][0] for i in range(9)]
ax2.set_title('Traffic Simulations: {} cars, {} simulations'.format(num_cars, num_simulations), fontsize=20, fontweight='bold')
ax1.scatter(x[0], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax2.scatter(x[1], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax3.scatter(x[2], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax4.scatter(x[3], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax5.scatter(x[4], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax6.scatter(x[5], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax7.scatter(x[6], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax8.scatter(x[7], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax9.scatter(x[8], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
# Out:
# 30 cars, 9 simulations:
#   Mean speed: 17.0 m/s
#   Standard Deviation: 11.0
#   Recommended speed limit is 27.0 m/s

# %% [markdown]
# ##3. Traffic Simulation: 30 cars, 1000 Simulations

# %%
#Setting number of cars and number of simulations.
num_cars = 30
num_simulations = 1000

#Mean and standard deviation only include time interval 61 - 120 seconds. 
simulations_1000 = n_simulations(num_simulations, num_cars)
speeds_1000 = [simulations_1000[i][1][61:] for i in range(len(simulations_1000))]
mean_speeds_1000 = [np.mean(speeds_1000[i]) for i in range(len(speeds_1000))]
stdev_1000 = [np.std(speeds_1000[i]) for i in range(len(speeds_1000))]
print("{} cars, {} simulations:".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speeds_1000))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_1000))))
print("  Recommended speed limit is {} m/s".format(round(np.mean(mean_speeds_1000) + np.mean(stdev_1000))))
# Out:
# 30 cars, 1000 simulations:
#   Mean speed: 16.0 m/s
#   Standard Deviation: 11.0
#   Recommended speed limit is 27.0 m/s

# %%
#Range of car speeds 
print("Slowest car: {} m/s".format(round(np.min(mean_speeds_1000))))
print("Fastest car: {} m/s".format(round(np.max(mean_speeds_1000))))
# Out:
# Slowest car: 12.0 m/s
# Fastest car: 23.0 m/s

# %% [markdown]
# ###3a. Frequency of speeds after 1000 simulations

# %%
plt.hist(mean_speeds_1000, bins=20)
plt.xlabel("Mean Speeds of Cars")
plt.ylabel("Frequency")
plt.title("Mean Speeds of 1000 Trials")
plt.subplots_adjust(left=10, right=11, top=11, bottom=10)
ymin, ymax = plt.ylim()
mean = np.mean(mean_speeds_1000)
stdev = np.mean(stdev_1000)
plt.vlines(mean, ymin, ymax, color="red")
plt.vlines([mean - stdev, mean + stdev], ymin, ymax, linestyles="dashed", color="red")
plt.text(20, 127, "Mean: {}".format(round(np.mean(mean_speeds_1000))), color='r') 
plt.text(20, 120, "StDev: {}".format(round(np.mean(stdev_1000))), color='r')
plt.show()

# %% [markdown]
# ##4. 3-D Plot: Location, Speed and Time

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = nine_simulations[8][0]
y = nine_simulations[8][1]
z = [[i]*30 for i in range(121)]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
fig.set_size_inches(12, 10)
ax.scatter(x, y, z, marker="|")
ax.set_xlabel("Road (meters)", fontsize=12)
ax.set_ylabel("Speed (meters/second)", fontsize=12)
ax.set_zlabel("Time (seconds)")
plt.title("3-D Traffic Simulation for Number 8", fontsize=15)

# %% [markdown]
# #Road Capacity Simulations

# %% [markdown]
# Varying the number of cars in the 1km roadway to identify optimal road capacity and speed limit

# %% [markdown]
# ##1. 20 cars, 100 simulations

# %%
num_cars = 20
num_simulations = 100
nine_simulations = n_simulations(num_simulations, num_cars)
speeds_of_nine = [nine_simulations[i][1][61:] for i in range(len(nine_simulations))]
mean_speeds_of_nine = [np.mean(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
stdev_of_nine = [np.std(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
print("{} cars, {} simulations".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speeds_of_nine))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_of_nine))))
print("  Recommended speed limit based on road capacity {} m/s".format(round(np.mean(mean_speeds_of_nine) +np.mean(stdev_of_nine))))

f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex='col', sharey='row')
plt.subplots_adjust(left=18, right=20, top=20, bottom=18)
y = [[i]*num_cars for i in range(121)]
x = [nine_simulations[i][0] for i in range(9)]
ax2.set_title('Traffic Simulations: {} cars, {} simulations'.format(num_cars, num_simulations), fontsize=20, fontweight='bold')
ax1.scatter(x[0], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax2.scatter(x[1], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax3.scatter(x[2], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax4.scatter(x[3], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax5.scatter(x[4], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax6.scatter(x[5], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax7.scatter(x[6], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax8.scatter(x[7], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax9.scatter(x[8], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
# Out:
# 20 cars, 100 simulations
#   Mean speed: 31.0 m/s
#   Standard Deviation: 4.0
#   Recommended speed limit based on road capacity 35.0 m/s

# %% [markdown]
# ##2. 30 cars, 100 simulations

# %%
num_cars = 30
num_simulations = 100
nine_simulations = n_simulations(num_simulations, num_cars)
speeds_of_nine = [nine_simulations[i][1][61:] for i in range(len(nine_simulations))]
mean_speeds_of_nine = [np.mean(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
stdev_of_nine = [np.std(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
print("{} cars, {} simulations".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speeds_of_nine))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_of_nine))))
print("  Recommended speed limit based on road capacity {} m/s".format(round(np.mean(mean_speeds_of_nine) +np.mean(stdev_of_nine))))

f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex='col', sharey='row')
plt.subplots_adjust(left=18, right=20, top=20, bottom=18)
y = [[i]*num_cars for i in range(121)]
x = [nine_simulations[i][0] for i in range(9)]
ax2.set_title('Traffic Simulations: {} cars, {} simulations'.format(num_cars, num_simulations), fontsize=20, fontweight='bold')
ax1.scatter(x[0], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax2.scatter(x[1], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax3.scatter(x[2], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax4.scatter(x[3], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax5.scatter(x[4], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax6.scatter(x[5], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax7.scatter(x[6], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax8.scatter(x[7], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax9.scatter(x[8], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
# Out:
# 30 cars, 100 simulations
#   Mean speed: 16.0 m/s
#   Standard Deviation: 10.0
#   Recommended speed limit based on road capacity 27.0 m/s

# %% [markdown]
# ##3. 40 cars, 100 simulations

# %%
num_cars = 40
num_simulations = 100
nine_simulations = n_simulations(num_simulations, num_cars)
speeds_of_nine = [nine_simulations[i][1][61:] for i in range(len(nine_simulations))]
mean_speeds_40 = mean_speeds_of_nine = [np.mean(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
stdev_40 = stdev_of_nine = [np.std(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
print("{} cars, {} simulations".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speeds_of_nine))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_of_nine))))
print("  Recommended speed limit based on road capacity {} m/s".format(round(np.mean(mean_speeds_of_nine) +np.mean(stdev_of_nine))))

f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex='col', sharey='row')
plt.subplots_adjust(left=18, right=20, top=20, bottom=18)
y = [[i]*num_cars for i in range(121)]
x = [nine_simulations[i][0] for i in range(9)]
ax2.set_title('Traffic Simulations: {} cars, {} simulations'.format(num_cars, num_simulations), fontsize=20, fontweight='bold')
ax1.scatter(x[0], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax2.scatter(x[1], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax3.scatter(x[2], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax4.scatter(x[3], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax5.scatter(x[4], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax6.scatter(x[5], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax7.scatter(x[6], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax8.scatter(x[7], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax9.scatter(x[8], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
# Out:
# 40 cars, 100 simulations
#   Mean speed: 11.0 m/s
#   Standard Deviation: 9.0
#   Recommended speed limit based on road capacity 20.0 m/s

# %% [markdown]
# ##3a. Mean Speeds for 40 cars

# %%
plt.hist(mean_speeds_40, bins=20)
plt.xlabel("Mean Speeds of Cars")
plt.ylabel("Frequency")
plt.title("Mean Speeds of 40 cars for 100 simulations")
plt.subplots_adjust(left=9, right=10, top=10, bottom=9)
ymin, ymax = plt.ylim()
mean = np.mean(mean_speeds_40)
stdev = np.mean(stdev_40)
plt.vlines(mean, ymin, ymax, color="red")
plt.vlines([mean - stdev, mean + stdev], ymin, ymax, linestyles="dashed", color="red")
plt.text(15, 7.75, "Mean {}".format(round(mean)), color='r')
plt.text(15, 7, "St.Dev {}".format(round(stdev)), color='r')
plt.show()

# %% [markdown]
# ##4. 50 cars, 100 simulations

# %%
num_cars = 50
num_simulations = 100
nine_simulations = n_simulations(num_simulations, num_cars)
speeds_of_nine = [nine_simulations[i][1][61:] for i in range(len(nine_simulations))]
mean_speeds_of_nine = [np.mean(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
stdev_of_nine = [np.std(speeds_of_nine[i]) for i in range(len(speeds_of_nine))]
print("{} cars, {} simulations".format(num_cars, num_simulations))
print("  Mean speed: {} m/s".format(round(np.mean(mean_speeds_of_nine))))
print("  Standard Deviation: {}".format(round(np.mean(stdev_of_nine))))
print("  Recommended speed limit based on road capacity {} m/s".format(round(np.mean(mean_speeds_of_nine) +np.mean(stdev_of_nine))))

f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, sharex='col', sharey='row')
plt.subplots_adjust(left=18, right=20, top=20, bottom=18)
y = [[i]*num_cars for i in range(121)]
x = [nine_simulations[i][0] for i in range(9)]
ax2.set_title('Traffic Simulations: {} cars, {} simulations'.format(num_cars, num_simulations), fontsize=20, fontweight='bold')
ax1.scatter(x[0], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax2.scatter(x[1], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax3.scatter(x[2], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax4.scatter(x[3], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax5.scatter(x[4], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax6.scatter(x[5], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax7.scatter(x[6], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax8.scatter(x[7], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
ax9.scatter(x[8], y, marker="|", c=['g', 'r', 'y', 'b', 'k'])
# Out:
# 50 cars, 100 simulations
#   Mean speed: 8.0 m/s
#   Standard Deviation: 7.0
#   Recommended speed limit based on road capacity 15.0 m/s

# %% [markdown]
# ##Mean speed and recommended speed limit based on number of cars.

# %%
x = [20, 30, 40, 50]
y_mean = [31, 16, 11, 8]
labels = []
plt.bar(x, y_mean, width=2, align='center', color=['g', 'b', 'y', 'r'])
plt.xlabel("Number of Cars")
plt.xticks(x, x)
plt.ylabel("Mean Speed (m/s)")
plt.title("Mean Speed Based on Number of Cars on Roadway")
plt.show()

# %%
y_rec_speed = [35, 27, 20, 15]
x = [20, 30, 40, 50]
labels = []
plt.bar(x, y_rec_speed, width=2, align='center', color=['g', 'b', 'y', 'r'])
plt.xlabel("Number of Cars")
plt.xticks(x, x)
plt.ylabel("Mean Speed (m/s)")
plt.title("Recommended Speed Limit Based on Number of Cars on Roadway")
plt.show()
