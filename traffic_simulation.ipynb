# %%
from traffic import Car, Road, Simulation
import statistics as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
sim = Simulation()

# %%
sim.run_simulation()

# %%
#sim.get_positions()

# %%
#sim.get_speeds()

# %%
for i in range(len(sim.car_positions)):
    print(i)
    print(sim.car_positions[i], sim.car_speeds[i])
# Out:
# 0
# [35, 68, 101, 134, 167, 200, 233, 266, 299, 330, 365, 398, 431, 464, 497, 528, 563, 596, 627, 660, 695, 728, 761, 794, 825, 860, 893, 926, 959, 992] [2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 0, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2]
# 1
# [39, 72, 105, 138, 171, 204, 237, 266, 303, 332, 369, 398, 435, 468, 501, 530, 567, 600, 629, 662, 699, 732, 765, 798, 827, 864, 897, 930, 963, 996] [4, 4, 4, 4, 4, 4, 4, 0, 4, 2, 4, 0, 4, 4, 4, 2, 4, 4, 2, 2, 4, 4, 4, 4, 2, 4, 4, 4, 4, 4]
# 2
# [41, 78, 111, 144, 173, 210, 243, 268, 309, 332, 375, 400, 441, 474, 507, 534, 573, 606, 633, 666, 705, 738, 771, 804, 831, 866, 903, 936, 969, 2] [2, 6, 6, 6, 2, 6, 6, 2, 6, 0, 6, 2, 6, 6, 6, 4, 6, 6, 4, 4, 6, 6, 6, 6, 4, 2, 6, 6, 6, 6]
# 3
# [45, 86, 119, 152, 177, 218, 251, 272, 317, 334, 383, 404, 449, 482, 515, 540, 581, 614, 639, 672, 713, 746, 779, 812, 837, 870, 911, 944, 977, 10] [4, 8, 8, 8, 4, 8, 8, 4, 8, 2, 8, 4, 8, 8, 8, 6, 8, 8, 6, 6, 8, 8, 8, 8, 6, 4, 8, 8, 8, 8]
# 4
# ...

# %%
y1 = [sim.car_speeds for i in range(len(sim.car_speeds))]
x1 = [sim.car_positions for i in range(len(sim.car_positions))]
plt.scatter(x1, y1, c="green")
plt.xlabel("Position", fontsize=15)
plt.ylabel("Speed", fontsize=15)
plt.title("Traffic Simulation", fontsize=15)
plt.show()

# %%
for position in sim.car_positions:
    plt.scatter(position, range(len(position)), color='green')
plt.xlabel("Position", fontsize=15)
plt.ylabel("Speed", fontsize=15)
plt.title("Traffic Simulation", fontsize=15)
plt.show()
